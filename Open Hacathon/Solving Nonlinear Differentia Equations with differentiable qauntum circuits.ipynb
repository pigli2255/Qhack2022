# %%
import inspect
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import importlib.util

#from smarty.neuralNetworks import callbacks
#from smarty.neuralNetworks.configs import AdamConfig, ExponentialDecayConfig, FlatLrConfig, LbfgsConfig, SGDConfig
#from smarty import TORCH_AVAILABLE
#from smarty import doe

import sys
import os

#from smarty.neuralNetworks.neuralNetworksMisc import CreateTensorDataset
#from smarty.neuralNetworks.trainer import DatasetTrainer


#if TORCH_AVAILABLE:
import torch
from torch.utils.data import DataLoader
from torch.optim import LBFGS
        
    #from neuralNetworks.callbacks import LogMetricsData, LogMetrics
    #from neuralNetworks import callbacks
    #from quantumModels.QPINNBase import QPinnBase
    #from quantumModels.QuantumModels import QDNN, ProductFeatureMap

# %% [markdown]
# ## Evolution Enhanced Feature Maps

# %% [markdown]
# Starting from paper: https://arxiv.org/abs/2011.10395
#
# After the set of single qubit rotations (dataencoding), we consider another unitary exp(-iH$\tau$) which acts for time $\tau$ and is generated by the Hamiltonian $H$.
# $H$ is chosen to be a complex many body Hamiltonian, to ensure that exponentially many amplitudes are generated.
# (Additionally, we plan an evolution layer that is parameter dependent_ $\tau\rightarrow\tau(x)$.)

# %% [markdown]
# #### Differential Equations with highly nontrivial dynamics
#
# $$\frac{\partial^2 u}{\partial x^2}=1 ~~~\text{with b.c.}~~~ u(x=-1)=u(x=1)=0 \\
# \rightarrow u(x)=\frac{1}{2}(x^2-1)$$
#
# For now: we chose a nearest neighbor Ising Hamiltonian $H=-J\sum_jZ_jZ_{j+1}+h\sum_jX_j$ with a fixed evolution time $\tau=2$ and J and h being drawn uniformly from (0,1].
#
# We use AdamOptimizer with lr=0.01 & 200 operations. Set $u_0=0.75$ and train with 100 points. Cost choice of total magnetization in the $z-$direction ($\hat{C}\sum_jZ_j$) and a Hardware-Efficient Ansatz of depth=6 is used.

# %% [markdown]
# #### Defining the Hamiltonian Time evolution:

# %%
qml.ApproxTimeEvolution(H, tau, n) # I don't need to specify the wires as this is alrady done in H

# %% [markdown]
# #### Defining the Hamiltonian

# %%
n_qubits = 6

J = np.random.rand(1)
h = np.random.rand(1) 

obs1 = [qml.PauliZ(j)@qml.PauliZ(j+1) for j in range(n_qubits-1)]
obs2 = [qml.PauliX(j) for j in range(n_qubits)]

coeffs1 = [J for i in range(n_qubits-1)]
coeffs2 = [h for i in range(n_qubits)]

obs = obs1 + obs2
coeffs = coeffs1 + coeffs2

H = qml.Hamiltonian(coeffs, obs)

print(H)
# Out:
#   ([0.3481828]) [X0]
# + ([0.3481828]) [X1]
# + ([0.3481828]) [X2]
# + ([0.3481828]) [X3]
# + ([0.3481828]) [X4]
# + ([0.3481828]) [X5]
# + ([0.41191526]) [Z0 Z1]
# + ([0.41191526]) [Z1 Z2]
# + ([0.41191526]) [Z2 Z3]
# + ([0.41191526]) [Z3 Z4]
# + ([0.41191526]) [Z4 Z5]

# %% [markdown]
# #### Defining the Tower Chebyshev feature maps

# %%
n_qubits = 6
depth = 1
layers = 1

dev = qml.device("default.qubit", wires = n_qubits)

# parameters #
tau = 2  # evolution time
n = 10 # order of trotterization 

# Hamiltonian
J = np.random.rand(1)
h = np.random.rand(1) 

obs1 = [qml.PauliZ(j)@qml.PauliZ(j+1) for j in range(n_qubits-1)]
obs2 = [qml.PauliX(j) for j in range(n_qubits)]
coeffs1 = [J for i in range(n_qubits-1)]
coeffs2 = [h for i in range(n_qubits)]
obs = obs1 + obs2
coeffs = coeffs1 + coeffs2

H = qml.Hamiltonian(coeffs, obs)

# end parameters#


# Define possible feature maps

# Tower Chebyshev feature map
def TChebyshev(x):
    for layer in range(layers):
        for i in range(n_qubits):
            qml.RY(2*i*np.arccos(x), wires=i)

# Evolution ehanced feature map
def EvolutionEnhanced(x, H, tau = 2, n = 10):
    TChebyshev(x, H, tau, n)
    qml.ApproximateTimeEvolution(H, tau, n)


# Define the Hardware-Efficient Ansatz
def HardwareEffAnsatz(params):
    for _ in range(depth):
        for l in range(n_qubits):
            qml.RZ(params[l,0], wires=l)
            qml.RX(params[l,1], wires=l) 
            qml.RZ(params[l,2], wires=l)
        for l in range(0, n_qubits-1, 2):
            qml.CNOT(wires=[l,l+1])
        for l in range(1, n_qubits-1, 2):
            qml.CNOT(wires=[l,l+1])
        

@qml.qnode(dev)
def VQA_TC(x, params):
    TChebyshev(x)
    HardwareEffAnsatz(params)
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)] # Use total magnetization as cost function

# %%
weights = np.random.randn(n_qubits, 3, requires_grad=True)
output=VQA_TC(np.pi/4, weights)
print(output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3260/1488244708.py in <module>
#       1 weights = np.random.randn(n_qubits, 3, depth, requires_grad=True)
# ----> 2 output=VQA_TC(np.array([1]), weights)
#       3 print(output)
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\qnode.py in __call__(self, *args, **kwargs)
#     558         self._tape_cached = using_custom_cache and self.tape.hash in cache
#     559
# --> 560         res = qml.execute(
#     561             [self.tape],
#     562             device=self.device,
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\interfaces\batch\__init__.py in execute(tapes, device, gradient_fn, interface, mode, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     340     if gradient_fn == "backprop" or interface is None:
#     341         return batch_fn(
# --> 342             cache_execute(batch_execute, cache, return_tuple=False, expand_fn=expand_fn)(tapes)
#     343         )
#     344
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\interfaces\batch\__init__.py in wrapper(tapes, **kwargs)
#     171         else:
#     172             # execute all unique tapes that do not exist in the cache
# --> 173             res = fn(execution_tapes.values(), **kwargs)
#     174
#     175         final_res = []
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\interfaces\batch\__init__.py in fn(tapes, **kwargs)
#     123         def fn(tapes, **kwargs):  # pylint: disable=function-redefined
#     124             tapes = [expand_fn(tape) for tape in tapes]
# --> 125             return original_fn(tapes, **kwargs)
#     126
#     127     @wraps(fn)
#
# ~\.pyenv\pyenv-win\versions\3.9.6\lib\contextlib.py in inner(*args, **kwds)
#      77         def inner(*args, **kwds):
#      78             with self._recreate_cm():
# ---> 79                 return func(*args, **kwds)
#      80         return inner
#      81
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\_qubit_device.py in batch_execute(self, circuits)
#     287             self.reset()
#     288
# --> 289             res = self.execute(circuit)
#     290             results.append(res)
#     291
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\_qubit_device.py in execute(self, circuit, **kwargs)
#     199
#     200         # apply all circuit operations
# --> 201         self.apply(circuit.operations, rotations=circuit.diagonalizing_gates, **kwargs)
#     202
#     203         # generate computational basis samples
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\devices\default_qubit.py in apply(self, operations, rotations, **kwargs)
#     214                 self._apply_basis_state(operation.parameters[0], operation.wires)
#     215             else:
# --> 216                 self._state = self._apply_operation(self._state, operation)
#     217
#     218         # store the pre-rotated state
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\devices\default_qubit.py in _apply_operation(self, state, operation)
#     239             return self._apply_ops[operation.base_name](state, axes, inverse=operation.inverse)
#     240
# --> 241         matrix = self._get_unitary_matrix(operation)
#     242
#     243         if operation in diagonal_in_z_basis:
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\devices\default_qubit.py in _get_unitary_matrix(self, unitary)
#     546             return unitary.get_eigvals()
#     547
# --> 548         return unitary.get_matrix()
#     549
#     550     @classmethod
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\operation.py in get_matrix(self, wire_order)
#    1279
#    1280     def get_matrix(self, wire_order=None):
# -> 1281         canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#    1282
#    1283         if self.inverse:
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\ops\qubit\parametric_ops.py in compute_matrix(theta)
#     180
#     181         return qml.math.diag([c, c]) + qml.math.stack(
# --> 182             [qml.math.stack([0, -s]), qml.math.stack([s, 0])]
#     183         )
#     184
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\math\multi_dispatch.py in wrapper(*args, **kwargs)
#     176             kwargs["like"] = interface
#     177
# --> 178             return fn(*args, **kwargs)
#     179
#     180         return wrapper
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\math\multi_dispatch.py in stack(values, axis, like)
#     541     """
#     542     values = np.coerce(values, like=like)
# --> 543     return np.stack(values, axis=axis, like=like)
#     544
#     545
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\autoray\autoray.py in do(fn, like, *args, **kwargs)
#      82         backend = infer_backend(like)
#      83
# ---> 84     return get_lib_fn(backend, fn)(*args, **kwargs)
#      85
#      86
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\pennylane\numpy\wrapper.py in _wrapped(*args, **kwargs)
#     115
#     116         # evaluate the original object
# --> 117         res = obj(*args, **kwargs)
#     118
#     119         if isinstance(res, _np.ndarray):
#
# ~\Desktop\TrainingProject\smarty-project\lib\site-packages\autograd\numpy\numpy_wrapper.py in stack(arrays, axis)
#      92     shapes = set(arr.shape for arr in arrays)
#      93     if len(shapes) != 1:
# ---> 94         raise ValueError('all input arrays must have the same shape')
#      95
#      96     result_ndim = arrays[0].ndim + 1
#
# ValueError: all input arrays must have the same shape

# %% [markdown]
# cost function: differential equation!

# %%
def output(x, params,H):
    mz = VQA_TC(x, params)
    return np.sum(mz)

def residual(self, controlPoints, params, H):
        """ Calculate the residium of the control points"""
        x = controlPoints
        u = output(x, params, H)

        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]
        u_xx = torch.autograd.grad(
            u_x, x,
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]
        f = u_xx - 1
        return f



def cost(params, x, H):
    return residual(x, params, H)**2

# %%
opt = qml.AdamOptimizer(0.1)

weights = np.random.randn(n_qubits, 3, depth, requies_grad=True)
controlPoints = np.random.randn(100, requires_grad=False)

weights = opt.step(cost, weights, x, H)
weights = np.clip(-np.pi, np.pi)

# %%
def collocationPoints(xBounds, numSamples=100):
    """Creates the data-points to train and evaluate the quantum network"""
    seed = 42
    generator = np.random.default_rng(seed)
    pointsInside = np.expand_dims(generator.uniform(xBounds[0], xBounds[1], numSamples), 1)
    pointsBoundary = np.expand_dims(np.take(xBounds, np.random.randint(0, 2, numSamples)), 1)

    return (pointsInside, pointsBoundary)

# %%
# Problem related parameters
xBounds = (-1., 1.)
boundaryValues = (0., 0.)
numTrainPoints = 300
pointsInside, pointsBdr = collocationPoints(xBounds, numTrainPoints)
# Create dataset with collocation points
dataset = CreateTensorDataset(pointsInside, pointsBdr, backend="torch")

# %% [markdown]
# ### Consider a rapidly oscillating non-persiodic solution.
# Initial Value problem:
# $$\frac{du}{dx}-4u+6u^2-sin(50x)-ucos(25x)+1/2 = 0, ~~~~~~ u(0)=u_0$$
