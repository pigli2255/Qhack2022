# %%
import inspect
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import importlib.util

import sys
import os

import torch
from torch.utils.data import DataLoader
from torch.optim import LBFGS

# without float32 complex numbers are cut off 
torch.set_default_dtype(torch.float32)

# %% [markdown]
# ## Evolution Enhanced Feature Maps

# %% [markdown]
# Starting from paper: https://arxiv.org/abs/2011.10395
#
# After the set of single qubit rotations (dataencoding), we consider another unitary exp(-iH$\tau$) which acts for time $\tau$ and is generated by the Hamiltonian $H$.
# $H$ is chosen to be a complex many body Hamiltonian, to ensure that exponentially many amplitudes are generated.
# (Additionally, we plan an evolution layer that is parameter dependent_ $\tau\rightarrow\tau(x)$.)

# %% [markdown]
# #### Differential Equations with highly nontrivial dynamics
#
# $$\frac{\partial^2 u}{\partial x^2}=1 ~~~\text{with b.c.}~~~ u(x=-1)=u(x=1)=0 \\
# \rightarrow u(x)=\frac{1}{2}(x^2-1)$$
#
# For now: we chose a nearest neighbor Ising Hamiltonian $H=-J\sum_jZ_jZ_{j+1}+h\sum_jX_j$ with a fixed evolution time $\tau=2$ and J and h being drawn uniformly from (0,1].
#
# We use AdamOptimizer with lr=0.01 & 200 operations. Set $u_0=0.75$ and train with 100 points. Cost choice of total magnetization in the $z-$direction ($\hat{C}\sum_jZ_j$) and a Hardware-Efficient Ansatz of depth=6 is used.

# %% [markdown]
# #### Defining the Hamiltonian

# %%
n_qubits = 6

J = np.random.rand(1)
h = np.random.rand(1) 

obs1 = [qml.PauliZ(j)@qml.PauliZ(j+1) for j in range(n_qubits-1)]
obs2 = [qml.PauliX(j) for j in range(n_qubits)]

coeffs1 = [J for i in range(n_qubits-1)]
coeffs2 = [h for i in range(n_qubits)]

obs = obs1 + obs2
coeffs = coeffs1 + coeffs2

H = qml.Hamiltonian(coeffs, obs)

print(H)

# %% [markdown]
# #### Defining the Tower Chebyshev feature maps

# %%
n_qubits = 6
depth = 5
layers = 1

dev = qml.device("default.qubit", wires = n_qubits)

# parameters #
tau = 2  # evolution time
n = 10 # order of trotterization 

# Hamiltonian
J = np.random.rand(1)
h = np.random.rand(1) 

obs1 = [qml.PauliZ(j)@qml.PauliZ(j+1) for j in range(n_qubits-1)]
obs2 = [qml.PauliX(j) for j in range(n_qubits)]
coeffs1 = [J for i in range(n_qubits-1)]
coeffs2 = [h for i in range(n_qubits)]
obs = obs1 + obs2
coeffs = coeffs1 + coeffs2

H = qml.Hamiltonian(coeffs, obs)

# end parameters#

# Define possible feature maps

# Tower Chebyshev feature map
def TChebyshev(x):
    for layer in range(layers):
        for i in range(n_qubits):
            qml.RY(2*i*torch.arccos(x), wires=i)


# Evolution ehanced feature map
def EvolutionEnhanced(x, H, tau = 2, n = 10):
    TChebyshev(x)
    qml.ApproximateTimeEvolution(H, tau, n)


# Define the Hardware-Efficient Ansatz
def HardwareEffAnsatz(params):
    for d in range(depth):
        for l in range(n_qubits):
            qml.RZ(params[l,0, d], wires=l)
            qml.RX(params[l,1, d], wires=l) 
            qml.RZ(params[l,2, d], wires=l)
        for l in range(0, n_qubits-1, 2):
            qml.CNOT(wires=[l,l+1])
        for l in range(1, n_qubits-1, 2):
            qml.CNOT(wires=[l,l+1])
        

@qml.qnode(dev, interface="torch")
def VQA_TC(inputs, params):
    TChebyshev(inputs)
    HardwareEffAnsatz(params)
    return [qml.expval(qml.PauliZ(i)) for i in range(n_qubits)] # Use total magnetization as cost function
 

weight_shapes = {"params": (n_qubits, 3, depth)}
layer = qml.qnn.TorchLayer(VQA_TC, weight_shapes)
model = torch.nn.Sequential(layer)

# %% [markdown]
# ### Fourier Series Ansatz
#
# A quantum circuit can be interpretet as an Fourier Series ansatz (see https://arxiv.org/abs/2008.08605) . Therefore a quantum model is written as
#
# $$ f_\theta(x) = \sum\limits_{\omega \in \Omega} c_\omega (\theta) ~ e^{i \omega x} $$
# or simply a Fourier sum. The circuit itself is a $l = | \Omega |$ repititive two types ansatz over $n$ qubits and $m \leq n$ inputs . The simplest form is as follows: First is the rotation type w.r.t.  parameters over all qubits. Second is the encoding type through Pauli rotations, again over all qubits. The two types are repeated $l$ times and finish with an last ($l+1$) rotation type. The measurement is taken from the first qubit.

# %%
n_qubits = r = 2
n_layers = 6

dev = qml.device('default.qubit', wires=r)

def S(x, scaling):
    """Data-encoding circuit block."""
    for i in range(r):
        qml.RX(*scaling * x, wires=i)
def W(theta):
    """Trainable circuit block."""
    for i in range(r):
        qml.Rot(*theta, wires=i)
@qml.qnode(dev, interface="torch", diff_method="best")
def VQA_TC(inputs, 
       theta, 
       scaling
      ):
    
    for j in range(n_layers):
        W(theta[j])  # W_j
        S(inputs, scaling[j]) # S_j with scalin
    W(theta[-1])     # W_last
        
    return qml.expval(qml.PauliZ(wires=0)) 

weight_shapes = {
                    "theta": (n_layers+1, 3), 
                    "scaling": (n_layers, 1)  # in case of variable scaling
                }

layer = qml.qnn.TorchLayer(VQA_TC, weight_shapes)
# c_layer1 = torch.nn.Linear(r, 1)
model = torch.nn.Sequential(layer)

# %% [markdown]
# cost function: differential equation!

# %%
def compute_output(outs):
    return torch.mean(outs)

def residual(controlPoints):
        """ Calculate the residium of the control points"""
        x = controlPoints
        u = compute_output(model(x))
        
        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        u_xx = torch.autograd.grad(
            u_x, x,
            grad_outputs=torch.ones_like(u_x),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        f = u_xx - 1
    
        return f

def cost(points):
    x = points[0]
    xBdr = points[1]
    BdrValue = 0
    residualLoss = residual(x)**2
    boundaryLoss = (BdrValue - compute_output(model(xBdr)))**2
    return residualLoss + boundaryLoss

# %%
num_train_point = 20
controlPoints = torch.rand(num_train_point, requires_grad=True)
controlPointsBdr = torch.tensor([-1,1]*int(num_train_point/2))

batches = torch.utils.data.DataLoader(torch.stack((controlPoints, controlPointsBdr),dim=1), batch_size=5, shuffle=True)

# %%
opt = torch.optim.Adam(model.parameters(), lr=0.1)
scheduler = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
steps = 50
model.train()

for i in range(steps):
    for batch in batches:
        loss = 0
        opt.zero_grad()
        for x in batch:
            loss += cost(x)
        loss=loss/len(batch)
        loss.backward(retain_graph=True)
        opt.step()
    #scheduler.step()
    if 0 == (i+1)%10 or i == 0:
        print("step: ", i+1, "--> loss = ", loss)
# Out:
# step:  1 --> loss =  tensor(1.3407, grad_fn=<DivBackward0>)
# step:  10 --> loss =  tensor(7.7425, grad_fn=<DivBackward0>)
# step:  20 --> loss =  tensor(0.2714, grad_fn=<DivBackward0>)
# step:  30 --> loss =  tensor(0.0501, grad_fn=<DivBackward0>)
# step:  40 --> loss =  tensor(0.0495, grad_fn=<DivBackward0>)
# step:  50 --> loss =  tensor(0.0107, grad_fn=<DivBackward0>)

# %%
def exactSolution(x):
    return 1/2*(x**2-1)

# %%
# Create plot Points
numPlotPoints = 20

model.eval()
plotPoints = np.linspace(-1, 1, numPlotPoints).reshape(numPlotPoints, 1)
yExact = exactSolution(plotPoints)
print(torch.tensor(plotPoints))
print([Point[0] for Point in torch.tensor(plotPoints)])
yModel = [compute_output(model(Point[0])).detach().numpy() for Point in torch.tensor(plotPoints)]

plt.plot(plotPoints, yExact, label = "Exact Solution")
plt.plot(plotPoints, yModel, label = "Model Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("u(x)", fontsize=14)
plt.legend()
#plt.savefig("ModelFit.png")

plt.show()
# Out:
# tensor([[-1.0000],
#         [-0.8947],
#         [-0.7895],
#         [-0.6842],
#         [-0.5789],
#         [-0.4737],
#         [-0.3684],
#         [-0.2632],
#         [-0.1579],
#         [-0.0526],
#         [ 0.0526],
#         [ 0.1579],
#         [ 0.2632],
#         [ 0.3684],
#         [ 0.4737],
#         [ 0.5789],
#         [ 0.6842],
#         [ 0.7895],
#         [ 0.8947],
#         [ 1.0000]], dtype=torch.float64)
# [tensor(-1., dtype=torch.float64), tensor(-0.8947, dtype=torch.float64), tensor(-0.7895, dtype=torch.float64), tensor(-0.6842, dtype=torch.float64), tensor(-0.5789, dtype=torch.float64), tensor(-0.4737, dtype=torch.float64), tensor(-0.3684, dtype=torch.float64), tensor(-0.2632, dtype=torch.float64), tensor(-0.1579, dtype=torch.float64), tensor(-0.0526, dtype=torch.float64), tensor(0.0526, dtype=torch.float64), tensor(0.1579, dtype=torch.float64), tensor(0.2632, dtype=torch.float64), tensor(0.3684, dtype=torch.float64), tensor(0.4737, dtype=torch.float64), tensor(0.5789, dtype=torch.float64), tensor(0.6842, dtype=torch.float64), tensor(0.7895, dtype=torch.float64), tensor(0.8947, dtype=torch.float64), tensor(1., dtype=torch.float64)]

# %% [markdown]
# ### Compute damped oscillator

# %% [markdown]
# $$\frac{du}{dx}+\lambda u(\kappa+\tan(\lambda\kappa))=0, ~~~~ u(0)=u_0$$
#
# This has a solution in the form of damped oscillating function
#
# $$u(x)=\exp(-\kappa\lambda x)\cos(\lambda x)+ const$$

# %%
import inspect
import pennylane as qml
from pennylane import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import importlib.util


import sys
import os

import torch
from torch.utils.data import DataLoader
from torch.optim import LBFGS

# without float32 complex numbers are cut off 
torch.set_default_dtype(torch.float32)
# Out:
# /home/miet_mr/git/examplesqml/venv/lib/python3.9/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ### Fourier Series with parallel Pauli
#
# Here a pallel fourier series type is implement by using the strong entangled layer.

# %%
n_qubits = 2
n_layers = 7
lamda_ = 8 #20
kappa = 0.1
u_0 = 1
var = 2
r = n_qubits

dev = qml.device('default.qubit', wires=r)

def S(x, scaling):
    """Data-encoding circuit block."""
    for i in range(r):
        qml.RX(*scaling * x, wires=i)
def W(weights):
    """Trainable circuit block."""
    qml.StronglyEntanglingLayers(weights, wires=range(r))

#    for i in range(r):
#        qml.Rot(*theta, wires=i)
@qml.qnode(dev, interface="torch", diff_method="best")
def parallel_quantum_model(inputs, 
                           weights, 
                           scaling
                          ):

    for j in range(n_layers):
        W(weights[j])  # W_j
        S(inputs, scaling[j]) # S_j with scalin
    W(weights[-1])     # W_last
        
    return qml.expval(qml.PauliZ(wires=0)) 

weight_shapes = {
                    "weights": (n_layers+1, 3, r, 3), # StronglyEntangledLayers : weight tensor of shape (L, M, 3)
                    "scaling": (n_layers, 1)  # in case of variable scaling each time
                }

layer = qml.qnn.TorchLayer(parallel_quantum_model, weight_shapes)
# c_layer1 = torch.nn.Linear(r, 1)
model2 = torch.nn.Sequential(layer)

def solutionDampedOscillator(x):
    y = 1/2*np.exp(-kappa*lamda_*x)*np.cos(lamda_*x) +  (1-u_0)
    return y 

def residual(controlPoints, lamda_=lamda_, kappa=kappa):
        """ Calculate the residium of the control points"""
        x = controlPoints
        u = torch.mean(model2(x))
        
        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]
        
        f = u_x + lamda_*u*(kappa + torch.tan(lamda_*x))
    
        return f
    
def cost(points):
    x = points[0]
    xBdr = points[1]
    BdrValue = 0
    residualLoss = residual(x)**2
    boundaryLoss = (BdrValue - torch.mean(model2(xBdr)))**2
    return residualLoss + 0.1*boundaryLoss

# %%
num_train_point = 20
#controlPoints = torch.rand(num_train_point, requires_grad=True)
controlPoints = torch.linspace(0,0.9, num_train_point,  requires_grad=True)
controlPointsBdr = torch.tensor([-1,1]*int(num_train_point/2))

batches = torch.utils.data.DataLoader(torch.stack((controlPoints, controlPointsBdr),dim=1),
                                      batch_size=5,
                                      shuffle=True)

# %%
opt = torch.optim.Adam(model2.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.8)
steps = 50
model2.train()

for i in range(steps):
    for batch in batches:
        loss = 0
        opt.zero_grad()
        for x in batch:
            c = cost(x)
            loss += c
        loss=loss/len(batch)
        loss.backward(retain_graph=True)
        opt.step()
    #scheduler.step()
    if 0 == (i+1)%10 or i == 0:
        print("step: ", i+1, "--> loss = ", loss)
# Out:
# step:  1 --> loss =  tensor(20.5543, grad_fn=<DivBackward0>)
# step:  10 --> loss =  tensor(20.4017, grad_fn=<DivBackward0>)
# step:  20 --> loss =  tensor(5.4353, grad_fn=<DivBackward0>)
# step:  30 --> loss =  tensor(8.4852, grad_fn=<DivBackward0>)

# %%
numPlotPoints = 101

model2.eval()
plotPoints = np.linspace(-1, 1, numPlotPoints).reshape(numPlotPoints, 1)
yExact = solutionDampedOscillator(plotPoints)
yModel = [(model2(Point[0])).detach().numpy() for Point in torch.tensor(plotPoints, dtype=torch.float32)]

plt.plot(plotPoints, yExact, label = "Exact Solution")
plt.plot(plotPoints, yModel, label = "Model Solution")
plt.xlabel("x", fontsize=14)
plt.ylabel("u(x)", fontsize=14)
plt.legend()
#plt.savefig("ModelFit.png")

plt.show()

# %% [markdown]
# ### Consider a rapidly oscillating non-periodic solution
# Initial Value problem:
# $$\frac{du}{dx}-4u+6u^2-sin(50x)-ucos(25x)+1/2 = 0, ~~~~~~ u(0)=u_0$$

# %%
def compute_output(outs):
    return torch.mean(outs)

def residual(controlPoints):
        """ Calculate the residium of the control points"""
        x = controlPoints
        u = compute_output(model(x))
        
        u_x = torch.autograd.grad(
            u, x,
            grad_outputs=torch.ones_like(u),
            retain_graph=True,
            create_graph=True,
            allow_unused=True
        )[0]

        f = u_x - 4*u + 6*u**2 - torch.sin(50*x) - u*torch.cos(25*x) + 1/2
    
        return f

def cost(points):
    x = points[0]
    xInit = points[1]
    InitValue = 0.75
    residualLoss = residual(x)**2
    initLoss = (InitValue - compute_output(model(xInit)))**2
    return residualLoss + initLoss
